# %% [markdown]
# <h1><center>House Prices: Advanced Regression Techniques</center> </h1>

# %% [markdown]
# Florian BLANCHET
# Hugo DARCHIS
# Juliette HOMASSEL

# %%
import csv

# %%
with open("train.csv", "r") as f:
    reader = csv.reader(f)
    training_set  = list(reader)

# %%
noms_categories = training_set[0]
data = training_set[1:]

# %%
data
# Out:
# [['1',
#   '60',
#   'RL',
#   '65',
#   '8450',
#   'Pave',
#   'NA',
#   'Reg',
#   'Lvl',
#   'AllPub',
#   'Inside',
#   'Gtl',
#   'CollgCr',
#   'Norm',
#   'Norm',
#   '1Fam',
#   '2Story',
#   '7',
#   '5',
#   '2003',
#   '2003',
#   'Gable',
#   'CompShg',
#   'VinylSd',
#   'VinylSd',
#   'BrkFace',
#   '196',
#   'Gd',
#   'TA',
#   'PConc',
#   'Gd',
#   'TA',
#   'No',
#   'GLQ',
#   '706',
#   'Unf',
#   '0',
#   '150',
#   '856',
#   'GasA',
#   'Ex',
#   'Y',
#   'SBrkr',
#   '856',
#   '854',
#   '0',
#   '1710',
#   '1',
#   '0',
#   '2',
#   '1',
#   '3',
#   '1',
#   'Gd',
#   '8',
#   'Typ',
#   '0',
#   'NA',
#   'Attchd',
#   '2003',
#   'RFn',
#   '2',
#   '548',
#   'TA',
#   'TA',
#   'Y',
#   '0',
#   '61',
#   '0',
#   '0',
#   '0',
#   '0',
#   'NA',
#   'NA',
#   'NA',
#   '0',
#   '2',
#   '2008',
#   'WD',
#   'Normal',
#   '208500'],
#  ['2',
#   '20',
#   'RL',
#   '80',
#   '9600',
#   'Pave',
#   'NA',
#   'Reg',
#   'Lvl',
#   'AllPub',
# ...
